# %%
pip install pandas

# %%
import pandas as pd

# %%
Movies_DF = pd.read_csv('movies.csv')

# %%
print(type(Movies_DF))
# Out:
# <class 'pandas.DataFrame'>

# %%
Movies_DF.head(30)
# Out:
#     index     budget                                     genres  \
# 0       0  237000000   Action Adventure Fantasy Science Fiction
# 1       1  300000000                   Adventure Fantasy Action
# 2       2  245000000                     Action Adventure Crime
# 3       3  250000000                Action Crime Drama Thriller
# 4       4  260000000           Action Adventure Science Fiction
# 5       5  258000000                   Fantasy Action Adventure
# 6       6  260000000                           Animation Family
# 7       7  280000000           Action Adventure Science Fiction
# 8       8  250000000                   Adventure Fantasy Family
# 9       9  250000000                   Action Adventure Fantasy
# 10     10  270000000   Adventure Fantasy Action Science Fiction
# 11     11  200000000            Adventure Action Thriller Crime
# 12     12  200000000                   Adventure Fantasy Action
# 13     13  255000000                   Action Adventure Western
# ...

# %%
Movies_DF.tail(20)
# Out:
#       index  budget                          genres  \
# 4783   4783       0                 Thriller Horror
# 4784   4784       0            Drama Comedy Romance
# 4785   4785       0                           Drama
# 4786   4786       0                  Comedy Romance
# 4787   4787       0        Science Fiction Thriller
# 4788   4788   12000             Horror Comedy Crime
# 4789   4789       0                           Drama
# 4790   4790       0                   Drama Foreign
# 4791   4791      13                          Horror
# 4792   4792   20000   Crime Horror Mystery Thriller
# 4793   4793       0                           Drama
# 4794   4794       0          Thriller Horror Comedy
# 4795   4795       0                           Drama
# 4796   4796    7000  Science Fiction Drama Thriller
# 4797   4797       0                Foreign Thriller
# 4798   4798  220000           Action Crime Thriller
# 4799   4799    9000                  Comedy Romance
# ...

# %%
Movies_DF.head(5)
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %%
Movies_index = Movies_DF.index

print("The values in the index column is : " , Movies_index)

print('\n')

print("The Data Type of the Index is     : " , type(Movies_index))
# Out:
# The values in the index column is :  RangeIndex(start=0, stop=4803, step=1)
#
#
# The Data Type of the Index is     :  <class 'pandas.RangeIndex'>

# %%
Movies_Col_Names = Movies_DF.columns

print("The Column Names are  : " , Movies_Col_Names)

print('\n')

print("The Data Type of the Column Names is     : " , type(Movies_Col_Names))
# Out:
# The Column Names are  :  Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director'],
#       dtype='str')
#
#
# The Data Type of the Column Names is     :  <class 'pandas.Index'>

# %%
Movies_Values = Movies_DF.values

print("The Values in the Dataframe are  : " , Movies_Values)

print('\n')

print("The Data Type of the Values is     : " , type(Movies_Values))
# Out:
# The Values in the Dataframe are  :  [[0 237000000 'Action Adventure Fantasy Science Fiction' ...
#   'Sam Worthington Zoe Saldana Sigourney Weaver Stephen Lang Michelle Rodriguez'
# ...

# %%
Movies_DF.info(2)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 4803 non-null   int64
#  1   budget                4803 non-null   int64
#  2   genres                4775 non-null   str
#  3   homepage              1712 non-null   str
#  4   id                    4803 non-null   int64
#  5   keywords              4391 non-null   str
#  6   original_language     4803 non-null   str
#  7   original_title        4803 non-null   str
#  8   overview              4800 non-null   str
#  9   popularity            4803 non-null   float64
#  10  production_companies  4803 non-null   str
#  11  production_countries  4803 non-null   str
#  12  release_date          4802 non-null   str
#  13  revenue               4803 non-null   int64
#  14  runtime               4801 non-null   float64
# ...

# %%
Movies_DF.dtypes
# Out:
# index                     int64
# budget                    int64
# genres                      str
# homepage                    str
# id                        int64
# keywords                    str
# original_language           str
# original_title              str
# overview                    str
# popularity              float64
# production_companies        str
# production_countries        str
# release_date                str
# revenue                   int64
# runtime                 float64
# spoken_languages            str
# status                      str
# tagline                     str
# title                       str
# vote_average            float64
# vote_count                int64
# cast                        str
# crew                        str
# director                    str
# dtype: object

# %%
Movies_DF.dtypes.value_counts(6)
# Out:
# str        0.666667
# int64      0.208333
# float64    0.125000
# Name: proportion, dtype: float64

# %%
Movies_DF['director']
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4          Andrew Stanton
#               ...
# 4798     Robert Rodriguez
# 4799         Edward Burns
# 4800          Scott Smith
# 4801          Daniel Hsia
# 4802     Brian Herzlinger
# Name: director, Length: 4803, dtype: str

# %%
Movies_DF.director
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4          Andrew Stanton
#               ...
# 4798     Robert Rodriguez
# 4799         Edward Burns
# 4800          Scott Smith
# 4801          Daniel Hsia
# 4802     Brian Herzlinger
# Name: director, Length: 4803, dtype: str

# %%
print(type(Movies_DF['director']))
# Out:
# <class 'pandas.Series'>

# %%
director = Movies_DF['director']
actor_1_fb_likes = Movies_DF['title']

print(type(director))
print(type(actor_1_fb_likes))
# Out:
# <class 'pandas.Series'>
# <class 'pandas.Series'>

# %%
print(director.head())

print('\n')  # Print an Empty Line 

print(actor_1_fb_likes.head(3))
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# 4       Andrew Stanton
# Name: director, dtype: str
#
#
# 0                                      Avatar
# 1    Pirates of the Caribbean: At World's End
# 2                                     Spectre
# Name: title, dtype: str

# %%
print(director.value_counts(5))
# Out:
# director
# Steven Spielberg    0.005657
# Woody Allen         0.004400
# Martin Scorsese     0.004190
# Clint Eastwood      0.004190
# Ridley Scott        0.003352
#                       ...
# Shane Carruth       0.000210
# Neill Dela Llana    0.000210
# Scott Smith         0.000210
# Daniel Hsia         0.000210
# Brian Herzlinger    0.000210
# Name: proportion, Length: 2349, dtype: float64

# %%
print(actor_1_fb_likes.describe())
# Out:
# count         4803
# unique        4800
# top       The Host
# freq             2
# Name: title, dtype: object

# %%
print(director.describe())
# Out:
# count                 4773
# unique                2349
# top       Steven Spielberg
# freq                    27
# Name: director, dtype: object

# %%
director.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4798    False
# 4799    False
# 4800    False
# 4801    False
# 4802    False
# Name: director, Length: 4803, dtype: bool

# %%
director_flled = director.fillna(0)

print("Count of Non Missing Values before applying fillna() :" ,director.count())
print("Count of Non Missing Values after applying fillna()  :" ,director_flled.count())
# Out:
# Count of Non Missing Values before applying fillna() : 4773
# Count of Non Missing Values after applying fillna()  : 4803

# %%
director_NA_Dropped = director.dropna()

print("Count of elements before applying dropna() :" ,director.size)
print("Count of elements after applying dropna()  :" ,director_NA_Dropped.size)
# Out:
# Count of elements before applying dropna() : 4803
# Count of elements after applying dropna()  : 4773

# %%
director * 3
# Out:
# 0                 James CameronJames CameronJames Cameron
# 1              Gore VerbinskiGore VerbinskiGore Verbinski
# 2                          Sam MendesSam MendesSam Mendes
# 3       Christopher NolanChristopher NolanChristopher ...
# 4              Andrew StantonAndrew StantonAndrew Stanton
#                               ...
# 4798     Robert RodriguezRobert RodriguezRobert Rodriguez
# 4799                 Edward BurnsEdward BurnsEdward Burns
# 4800                    Scott SmithScott SmithScott Smith
# 4801                    Daniel HsiaDaniel HsiaDaniel Hsia
# 4802     Brian HerzlingerBrian HerzlingerBrian Herzlinger
# Name: director, Length: 4803, dtype: str

# %%
vote_count = Movies_DF['vote_count']
vote_count / 100
# Out:
# 0       118.00
# 1        45.00
# 2        44.66
# 3        91.06
# 4        21.24
#          ...
# 4798      2.38
# 4799      0.05
# 4800      0.06
# 4801      0.07
# 4802      0.16
# Name: vote_count, Length: 4803, dtype: float64

# %%
vote_count = Movies_DF['vote_count']
vote_count /200
# Out:
# 0       59.000
# 1       22.500
# 2       22.330
# 3       45.530
# 4       10.620
#          ...
# 4798     1.190
# 4799     0.025
# 4800     0.030
# 4801     0.035
# 4802     0.080
# Name: vote_count, Length: 4803, dtype: float64

# %%
vote_count.isnull().sum()
# Out:
# np.int64(0)

# %%
Movies_DF2 = pd.read_csv('movies.csv', 
                        index_col='title')

print(Movies_DF2.head())
# Out:
#                                           index     budget  \
# title
# Avatar                                        0  237000000
# Pirates of the Caribbean: At World's End      1  300000000
# Spectre                                       2  245000000
# The Dark Knight Rises                         3  250000000
# John Carter                                   4  260000000
#
#                                                                             genres  \
# title
# Avatar                                    Action Adventure Fantasy Science Fiction
# Pirates of the Caribbean: At World's End                  Adventure Fantasy Action
# Spectre                                                     Action Adventure Crime
# The Dark Knight Rises                                  Action Crime Drama Thriller
# John Carter                                       Action Adventure Science Fiction
#
#                                                                               homepage  \
# ...

# %%
Movies_DF3 = Movies_DF.set_index('title')

print(Movies_DF3.head())
# Out:
#                                           index     budget  \
# title
# Avatar                                        0  237000000
# Pirates of the Caribbean: At World's End      1  300000000
# Spectre                                       2  245000000
# The Dark Knight Rises                         3  250000000
# John Carter                                   4  260000000
#
#                                                                             genres  \
# title
# Avatar                                    Action Adventure Fantasy Science Fiction
# Pirates of the Caribbean: At World's End                  Adventure Fantasy Action
# Spectre                                                     Action Adventure Crime
# The Dark Knight Rises                                  Action Crime Drama Thriller
# John Carter                                       Action Adventure Science Fiction
#
#                                                                               homepage  \
# ...

# %%
Movies_DF4 = Movies_DF3.reset_index()

Movies_DF4.head()
# Out:
#                                       title  index     budget  \
# 0                                    Avatar      0  237000000
# 1  Pirates of the Caribbean: At World's End      1  300000000
# 2                                   Spectre      2  245000000
# 3                     The Dark Knight Rises      3  250000000
# 4                               John Carter      4  260000000
#
#                                      genres  \
# 0  Action Adventure Fantasy Science Fiction
# 1                  Adventure Fantasy Action
# 2                    Action Adventure Crime
# 3               Action Crime Drama Thriller
# 4          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# ...

# %%
Movies_DF.columns.size
# Out:
# 24

# %%
Movies_DF['HEMANTH'] = Movies_DF.vote_count
+ Movies_DF.vote_count
+ Movies_DF.vote_count
# Out:
# 0       11800
# 1        4500
# 2        4466
# 3        9106
# 4        2124
#         ...
# 4798      238
# 4799        5
# 4800        6
# 4801        7
# 4802       16
# Name: vote_count, Length: 4803, dtype: int64

# %%
Movies_DF.columns.size
# Out:
# 25

# %%
# Drop the new column from the Dataframe

Movies_DF.drop('HEMANTH',axis='columns' , inplace=True)

# %%
Movies_DF.columns.size
# Out:
# 24

# %%
Movies_DF2 = pd.read_csv('movies.csv', 
                        index_col='title')
Movies_actor_director = Movies_DF2[['crew', 'cast', 'vote_count']]

Movies_actor_director.head()
# Out:
#                                                                                        crew  \
# title
# Avatar                                    [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...
# Pirates of the Caribbean: At World's End  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...
# Spectre                                   [{'name': 'Thomas Newman', 'gender': 2, 'depar...
# The Dark Knight Rises                     [{'name': 'Hans Zimmer', 'gender': 2, 'departm...
# John Carter                               [{'name': 'Andrew Stanton', 'gender': 2, 'depa...
#
#                                                                                        cast  \
# title
# Avatar                                    Sam Worthington Zoe Saldana Sigourney Weaver S...
# Pirates of the Caribbean: At World's End  Johnny Depp Orlando Bloom Keira Knightley Stel...
# Spectre                                   Daniel Craig Christoph Waltz L\u00e9a Seydoux ...
# ...

# %%
Movies_DF.dtype.counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22292\1133044428.py in ?()
# ----> 1 Movies_DF.dtype.counts()
#
# c:\Users\heman\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'
